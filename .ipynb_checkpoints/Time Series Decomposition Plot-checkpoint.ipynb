# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline

# %%
df = pd.read_excel('champagne-sales.xlsx')
df.head(3)
# Out:
#   Month  Champagne Sales
# 0  1-01             2851
# 1  1-02             2672
# 2  1-03             2755

# %%
df['period'] = df.Month.apply(lambda x: x.split('-')[0])
df['month'] = df.Month.apply(lambda x: x.split('-')[1]).astype(str)
df['year'] = (df.period.astype(int) + 2000).astype(str)
df['date'] = df.year + '-' + df.month
df.date = pd.to_datetime(df.date)

# Preparing particular nomenclature to work with FB Prophet package
df.rename(columns={'date':'ds', 'Champagne Sales':'y'}, inplace=True)
df.set_index(df.ds, inplace=True)

df.drop(columns=['Month','period','month','year', 'ds'], inplace=True)
df.head(2)
# Out:
#                y
# ds
# 2001-01-01  2851
# 2001-02-01  2672

# %% [markdown]
# ### Classical Decomposition (naive)

# %% [markdown]
# # TODO: after installing FBProphet via CONDA, this error started happening

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
result = sm.tsa.seasonal_decompose(df)
result.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-a676da4fe77a> in <module>
#       1 result = sm.tsa.seasonal_decompose(df)
# ----> 2 result.plot()
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/seasonal.py in plot(self)
#     179         fig, axes = plt.subplots(4, 1, sharex=True)
#     180         if hasattr(self.observed, 'plot'):  # got pandas use it
# --> 181             self.observed.plot(ax=axes[0], legend=False)
#     182             axes[0].set_ylabel('Observed')
#     183             self.trend.plot(ax=axes[1], legend=False)
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     983                              stacking_id=stacking_id,
#     984                              is_errorbar=is_errorbar,
# --> 985                              **kwds)
#     986             self._add_legend_handle(newlines[0], label, index=i)
#     987
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1022         ax._plot_data.append((data, cls._kind, kwds))
#    1023
# -> 1024         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1025         # set date formatter, locators and rescale limits
#    1026         format_dateaxis(ax, ax.freq, data.index)
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#     999             cls._initialize_stacker(ax, stacking_id, len(y))
#    1000         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
# -> 1001         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1002         cls._update_stacker(ax, stacking_id, y)
#    1003         return lines
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     613             else:
#     614                 args = (x, y)
# --> 615             return ax.plot(*args, **kwds)
#     616
#     617     def _get_index_name(self):
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1603
#    1604         for line in self._get_lines(*args, **kwargs):
# -> 1605             self.add_line(line)
#    1606             lines.append(line)
#    1607
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1883             line.set_clip_path(self.patch)
#    1884
# -> 1885         self._update_line_limits(line)
#    1886         if not line.get_label():
#    1887             line.set_label('_line%d' % len(self.lines))
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1905         Figures out the data limit of the given line, updating self.dataLim.
#    1906         """
# -> 1907         path = line.get_path()
#    1908         if path.vertices.size == 0:
#    1909             return
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/lines.py in recache(self, always)
#     638         if always or self._invalidx:
#     639             xconv = self.convert_xunits(self._xorig)
# --> 640             x = _to_unmasked_float_array(xconv).ravel()
#     641         else:
#     642             x = self._x
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1363         return np.ma.asarray(x, float).filled(np.nan)
#    1364     else:
# -> 1365         return np.asarray(x, float)
#    1366
#    1367
#
# ~/anaconda3_501/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'Period'

# %% [markdown]
# ### [STL Decomposition](https://pypi.org/project/stldecompose/)
# More advanced. In this implementation, the trend component is calculated by substituting a configurable **Loess regression** for the convolutional method used in seasonal_decompose.

# %%
try:
    import stldecompose as stl
except:
    ! pip install stldecompose
    
result_stl = stl.decompose(df.y)
result_stl.plot();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-1b66418fc084> in <module>
#       5
#       6 result_stl = stl.decompose(df.y)
# ----> 7 result_stl.plot();
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/seasonal.py in plot(self)
#     179         fig, axes = plt.subplots(4, 1, sharex=True)
#     180         if hasattr(self.observed, 'plot'):  # got pandas use it
# --> 181             self.observed.plot(ax=axes[0], legend=False)
#     182             axes[0].set_ylabel('Observed')
#     183             self.trend.plot(ax=axes[1], legend=False)
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            xlim=xlim, ylim=ylim, rot=rot, fontsize=fontsize,
#    2740                            colormap=colormap, table=table, yerr=yerr,
# -> 2741                            xerr=xerr, label=label, secondary_y=secondary_y,
#    2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000
#    2001 _shared_docs['boxplot'] = """
# -> 2002     Make a box plot from DataFrame columns.
#    2003
#    2004     Make a box-and-whisker plot from DataFrame columns, optionally grouped
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
# -> 1804
#    1805
#    1806 df_kind = """- 'scatter' : scatter plot
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     258             self._post_plot_logic(ax, self.data)
#     259
# --> 260     def _args_adjust(self):
#     261         pass
#     262
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     983             ax = self._get_ax(i)
#     984             kwds = self.kwds.copy()
# --> 985             style, kwds = self._apply_style_colors(colors, kwds, i, label)
#     986
#     987             errors = self._get_errorbars(label=label, index=i)
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1022         # column_num must be in kwds for stacking purpose
#    1023         freq, data = _maybe_resample(data, ax, kwds)
# -> 1024
#    1025         # Set ax with freq info
#    1026         _decorate_axes(ax, freq, kwds)
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#     999             lines = _get_all_lines(ax)
#    1000             left, right = _get_xlim(lines)
# -> 1001             ax.set_xlim(left, right)
#    1002
#    1003     @classmethod
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     613                 name = pprint_thing(name)
#     614
# --> 615         return name
#     616
#     617     @classmethod
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1603
#    1604         for line in self._get_lines(*args, **kwargs):
# -> 1605             self.add_line(line)
#    1606             lines.append(line)
#    1607
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1883             line.set_clip_path(self.patch)
#    1884
# -> 1885         self._update_line_limits(line)
#    1886         if not line.get_label():
#    1887             line.set_label('_line%d' % len(self.lines))
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1905         Figures out the data limit of the given line, updating self.dataLim.
#    1906         """
# -> 1907         path = line.get_path()
#    1908         if path.vertices.size == 0:
#    1909             return
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/lines.py in recache(self, always)
#     638         if always or self._invalidx:
#     639             xconv = self.convert_xunits(self._xorig)
# --> 640             x = _to_unmasked_float_array(xconv).ravel()
#     641         else:
#     642             x = self._x
#
# ~/anaconda3_501/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1363         return np.ma.asarray(x, float).filled(np.nan)
#    1364     else:
# -> 1365         return np.asarray(x, float)
#    1366
#    1367
#
# ~/anaconda3_501/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'Period'

# %% [markdown]
# # Model Training
# Now that we have decomposed the Time Series, it will provide valuable insight into the most likely appropriate parameters to use with time series forecasting models.
# Let's compare the performance of two of the most typical approaches: 1) ETS (AKA Holt-Winters); and 2) ARIMA (and its seasonal variations, SARIMAX).

# %% [markdown]
# ## Pre-processing
# Adjust the dataframe to work with `statsmodels` implementations, as well as setting the appropriate index as data-time, set target feature as double datatype (required by `statsmodels`), and split training/validation dataset:

# %%
# Check index is set as datetime data type
assert type(df.index) == pd.core.indexes.datetimes.DatetimeIndex

# %%
df.y = df.y.astype('double')

# %%
# Split Train/Validation. Last 6 months as validation

df_train = df.loc[df.index[:-6]]
df_test = df.loc[df.index[-6:]]

# %% [markdown]
# ## 1) ETS (Holt-Winters)

# %%
try:
    v = sm.version.version
except:
    v = sm.__version__
print(f'Statsmodels version has to be >= 0.10 | Current version is {v}')

# ! pip install statsmodels --upgrade

# Requires to restart kernel after installation
# Out:
# Statsmodels version has to be >= 0.10 | Current version is 0.10.0

# %%
# Necessary to use latest version of statsmodels (>= 0.10), otherwise throws error. 
from statsmodels.tsa.holtwinters import ExponentialSmoothing as ETS

model = ETS(df_train, trend=None, damped=False, seasonal_periods=12, seasonal='mul')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.

# %%
# %%timeit
forecast = model.fit()
# Out:
# 24.8 ms ± 1.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
yhat = forecast.forecast(6)
# Out:
# 14.2 ms ± 1.12 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.plot(yhat, ls='-', c='b')
plt.plot(df_test, ls=':', c='r')
# yhat.plot(style='-b')
# df_test.plot(style=':r')
print(yhat)
# Out:
# 2008-07-01     4074.576914
# 2008-08-01     2153.467925
# 2008-09-01     5172.220501
# 2008-10-01     6798.234148
# 2008-11-01    10175.086213
# 2008-12-01    12746.642866
# Freq: MS, dtype: float64

# %%
score_ETS = forecast.aic

# %%
forecast.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                   90
# Model:             ExponentialSmoothing   SSE                       27368860.251
# Optimized:                         True   AIC                           1164.260
# Trend:                             None   BIC                           1199.257
# Seasonal:                Multiplicative   AICC                          1171.712
# Seasonal Periods:                    12   Date:                 Wed, 10 Jul 2019
# Box-Cox:                          False   Time:                         11:11:41
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4558209                alpha                 True
# smoothing_seasonal             0.000000                gamma                 True
# initial_level                 3512.7504                  l.0                 True
# initial_seasons.0             0.7824597                  s.0                 True
# initial_seasons.1             0.7108668                  s.1                 True
# initial_seasons.2             0.8305901                  s.2                 True
# initial_seasons.3             0.8550848                  s.3                 True
# initial_seasons.4             0.9100867                  s.4                 True
# initial_seasons.5             0.9116496                  s.5                 True
# initial_seasons.6             0.7625533                  s.6                 True
# initial_seasons.7             0.4030195                  s.7                 True
# initial_seasons.8             0.9679763                  s.8                 True
# initial_seasons.9             1.2722832                  s.9                 True
# initial_seasons.10            1.9042579                 s.10                 True
# initial_seasons.11            2.3855224                 s.11                 True
# ---------------------------------------------------------------------------------
# """

# %% [markdown]
# ## 3) Prophet (Facebook) - TO BE SKIPPED until fix Time Series decompose plot
# Some extra steps are required to get this amazing package to work. Follow the installation instructions on the [Official FBProphetDocumentation](https://facebook.github.io/prophet/docs/installation.html), based on the appropriate OS/System.
#
# Let's install via Conda:

# %%
# 1) Install gcc and all requirements

# ! conda install gcc -y

# %%
# 2) Install fbprophet via Conda
# ! conda install -c conda-forge fbprophet -y

# %% [markdown]
# This package requires the dataframe to be structured in a very particular manner:
# + Date component named as "ds"
# + Feature of interest named as "y"
